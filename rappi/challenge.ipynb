# %% [markdown]
# # Business Intelligence / Business Analyst, Lead
# ## Business Case
#
# ----
#
# Welcome to the RappiPay challenge for Business Intelligence / Business Analyst.
# From the interview we had, we can already tell that you’re a very knowledgeable
# professional that we would love to call teammate. In this challenge, we are looking
# for ownership: ownership of the decisions, ownership of the data, and ownership of
# the business, hence imagine you’re already a crucial part of the team and that many
# business decisions rely on your analysis. Let’s get started...
#
# ![](https://i.blogs.es/2b545d/rappi-1/1366_2000.jpg)
#
# # Question 1
#
# 1. We just launched the credit card to market. As you might be aware, everyone
# was extremely busy planning and developing the product, but no one thought of
# coming up nor monitoring the key performance indicators of the business. **What
# would be the key performance indicators you would come up as the most important
# to monitor a credit card business? How often would you suggest such indicators must
# be monitored?**
#
#
# #### **Delinquency Rates**
# First at all, the core of business is the credit, then our main risk is **delinquency rate** measured to DPD (Days past Due) in interval of time because we can calculate two additionals metrics: **Roll rates** that is the percentage of cardholders that roll from one category of delinquency to the next that is an input for collection team for attending specific bucket and the other hand, by customer classification for identifying potencial risk in specific type of customer and can take actions about this for achieving the company goals and finance strategies.
#
# #### **Risk Acceptance Rate**
#
# Customer acquisition is very important given that exist a budget assigned to Marketing team and is the path toward the achieving goals of financial planning in terms of allocated cards and credit card lines granted. **Risk Models and Rules** plays an important role because are the main tools for customer evaluation and one way to evaluate this tools is calculate **Risk Acceptance Rate** and so, we can take actions in terms of adjusting **cut off strategies** depend of de **risk appetite statement**, i mean, the delinquency rate is a function of risk acceptance **"Higher acceptance rate, higher delinquency rates, but more customers, and so on".**
#
# Risk appetite statement (Stablished for risk management team) is important for business goals to same that Modeling team (Normally Data Science Team) in terms of scores assigned by the model. Model evaluation step that include several metrics like precision, recall, accuracy, AUC, ROC and so on; determine better classification and therefore, improve evaluation for acquire better customers given probability distributions.
#
# #### **General Acceptance Rate**
#
# Knowing the product funnel, we know that there is not only a risk and fraud model, there are also other steps which could make the acceptance or granting of the card lower. Therefore, it is also important to analyze the **reasons for rejection.**
#
# #### **Credit lines**
#
# Each customer has different needs, so for this is important study the usage of credit lines in function of **Delinquency rates, mean transactions and financial healt** because born new concepts like: **Risk Based Pricing** where we can adjust current interest rates and credit line amount customized like an experiment and posteriorly, measure financial risk in terms of default ,satisfaction and loyalty toward the enterprise in customer segmentation or control groups evaluated for an specific model and response variable. An example of metric is **Mean Usage of Credit Lines** for knowing if in fact, we have lower credit lines of the competitors and if we can take more risk (To raise Amounts).
#
# The goal is to improve credit conditions and grow steadily.
#
#
# #### **Cost of acquisitions**
#
# How much do you spend on acquiring users? This is the importance to evaluate correctly users (Models and has efficient funnel) and accepting as many users as possible as well as achieve financial goals and inclusion (Many people must have access to financial products😄).
#
#
# #### **Customer satisfaction - Net promoter score**
#
# Based on user experience information area. This result will be useful to make modifications to the product.
#
#
# **In general, I would monitor these KPI's weekly and monthly for customer satisfaction. Batch Data Arquitecture will be enough for this propuse with one-lag days.**
#
#
# # Question 2
#
# ----
#
# 2. Dealing with diverse stakeholders is difficult. Where one might interpret a
# concept in a way, another one might differ from such interpretation. Let’s take for
# example the concept ‘dormant’: some stakeholders might interpret the dormant
# customer as one that has not done any transactions in 6 months, where another one
# might say it takes only 4 months to reach this state. Propose a problem resolution
# strategy with the stakeholders. **How would you deal with this issue? Which facts would
# you present?**
#
# This can be as simple as just thinking that not everyone is an expert on a subject. The best way to avoid ambiguity errors is to create a first of all is to clarify the situation with the analyst or the area in order and as a later step, within these analytical areas create a **statement of main metrics** which its objective is to be concise and accurate in the way we measure and present data, this is part of data governance followed by the pillar **"Identify the type of data you have".**
#
# I would present historical data where would look labels some customer with the correct concept and present the statement and that supports said label
#
#
# # Question 3
#
# ----
#
# 3. It is a common practice to have many systems scattered all over: where one
# might be hosting the app, others might be hosting models needed for daily
# operations. This usually benefits usability over scalability. Nevertheless, data
# centralization is crucial for data exploitation. For simplicity, imagine there are 4
# systems:
#     - The first system hosts the app. It generates data that is stored in an
# internal database (ignore the database’s architecture for now). Every time
# the user interacts with a screen, clicks a button, or opens the app, this is stored
# as an event.
#     - The second system hosts the risk model. Every time a customer asks for
# a credit, the system retrieves the risk data from the credit bureau and
# evaluates whether the customer is prone to be a defaulter.
#     - The third system hosts the customers information. Here, unrestricted
# information is hosted. This database contains the name, address, email, etc...
#     - Finally, the fourth and last system hosts all the payments information, this
# means, all the information related to the usage of the credit card: swipes,
# payments, recurrent payments, credit line, etc.
#
# All systems share a unique identifier for all of our customers. This is the key that allows
# data to be joined on other databases.
#
# **What should we do to centralize the data in order to display it in charts for KPI monitoring?**
#
# Create un **Enterprise Data Lake**, because is a centralized data repository for large amounts of data that can help all users in the organization, use Non-relational and relational data, query results faster, essential to Data scientists, Data developers, and Business analysts, secure and consistency raw data. For example, in AWS would use **AWS Lake Formation Service** using OLAP - Online analytical processing (RedShift) or OLTP - Online Transaction Processing (RDS, Aurora) which the end destination can be AWS Athena and query directly parquet file from S3 Bucket and visualize data in Quicksight service or Tableau (Any BI Tool).
#
# I will leave an example of the architecture:
#
# ![](https://d1.awsstatic.com/partner-network/partner_marketing_web_team/AWS%20Lake%20Formation_%20How%20It%20Works.2d4c8b2ae5fbc0e22e4444b543e97b912ebf1892.png)
#
# **What would you propose the data governance strategy should be?**
#
# **Best Practice for Access Control**, i mean, create role and groups for distinct analytical areas or stakeholders.
#
#
# # Practice case
# ----
#
# 4. Download the attached .csv file. Preferably upload it to a SQL db and query your way
# through the challenge.
#
#
#    - Your task is to exploit the information contained in the aforementioned file as you
#     find fit. Some things to take into consideration:
#    - This database contains credit card information and transactions from
#     multiple customers. Use your favorite data visualization tool / programming language
#     to explore the data and present the results [R, Python, PowerBI, Spotfire, etc...]. The
#     database has the following architecture:
#
#
# |Variable | Description|
# |-----------|:-----------:
# ID |  This is the user’s unique identifier.
# UPDATE | Date when the event happened.
# STATUS | The event, which can take the following values: **EMPTY** - The user did not respond to the communication OR there was  a transaction (this is reflected in the TXN column). **RESPONSE** – The customer responded to the MKT campaign. **RISK** – The customer was checked on the risk model whether the  customer is fit to get a credit or not. **REJECTED** – The risk model determined the customer is not fit to get a  credit.  **APPROVED** – The risk model determined the customer as fit to get a credit. The customer is granted a credit. Here some of the other  columns are populated.  **DELIVERED** – The customer received a physical credit card.
# MOTIVE | The reason of rejection OR the type of card.
# INTEREST_RATE |  The interest rate of the customer’s credit card.
# AMOUNT | The amount of the credit granted to the customer.
# CAT | The annual cost of the credit granted to the customer.
# TXN | The amount of each transaction for each customer.
# CP | Zip Code where the physical credit card was delivered to.
# DELIVERY_SCORE | A score the customer gives to the delivery company for the  delivery service.
#
#
# Usually, the sign-up process starts when the customer responded to the communication, and ends-up with an approval, either with physical or digital card.
#
#
# ----

# %% [markdown]
# # System information

# %%
import sys
import platform

print("System Info")
print('----------------------------------------------------')
print("""Python version: %s
system: %s
machine: %s
platform: %s
""" % (
sys.version.split('\n'),
platform.system(),
platform.machine(),
platform.platform()
))
# Out:
# System Info
# ----------------------------------------------------
# Python version: ['3.7.3 (default, Mar 27 2019, 22:11:17) ', '[GCC 7.3.0]']
# system: Linux
# machine: x86_64
# platform: Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-debian-bullseye-sid

# %% [markdown]
# # Exploratory Data Analysis

# %%
from bi_config import rappi_db as rappi
import pandas as pd
pd.pandas.set_option('display.max_columns',None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import sys
import datetime 
from datetime import date, timedelta

# Initialize rappi database

rappi.connect('rappi_data')

# Upload table to rappi_data db

rappi.upload_table('BusinessBIBA_Challenge')

# Instance query table method from rappi_db class

query = rappi.get_query_table

# Current table in rappi_data

rappi.show_tables()
# Out:
# Connection Established to rappi_db
# Connection Established to rappi_db
# Connection Established to rappi_db
# [('credit_card_data',)]

# %% [markdown]
# ## Data Structure

# %%
dataset = """
SELECT 
ID,
strftime('%H:%M:00',substr(APPLICATION_DATE, 1, 8)) as DATE,
STATUS,
MOTIVE,
CAST(INTEREST_RATE AS INTEGER) as INTEREST_RATE,
CAST(AMOUNT AS REAL) as AMOUNT,
CAST(CAT AS INTEGER) as CAT,
CAST(TXN AS NUMERIC) as TXN,
CAST(CP AS TEXT) as CP,
CAST(DELIVERY_SCORE AS TEXT) as DELIVERY_SCORE
FROM credit_card_data
"""

data = query(dataset)
data.info()
division = '-'*55

# Data Structure
print('\nData Records')
print(division)

cat_vars = [var for var in data.columns if data[var].dtype == 'O']
print('Number of categorical variables:', len(cat_vars))

num_vars = [var for var in data.columns if data[var].dtype == 'float64']
print('Number of numerical variables:', len(num_vars))

##Chec NA values through the variables
var_with_na = [var for var in data.columns if data[var].isnull().sum()>0]
cat_na = [var for var in cat_vars if var in var_with_na]
num_na = [var for var in num_vars if var in var_with_na]

print('Number of categorical variables with NA:', len(cat_na),'----------->', cat_na)
print('Number of numerical variables with NA:', len(num_na),'---------->', num_na)
print(division)
print(f'Shape of matrix format: {data.shape}')
print(division)
users = data['ID'].nunique()
print(f'Unique Customers: {users}')
# Out:
# Connection Established to rappi_db
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12756 entries, 0 to 12755
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              12756 non-null  int64
#  1   DATE            12756 non-null  object
#  2   STATUS          7940 non-null   object
#  3   MOTIVE          2298 non-null   object
#  4   INTEREST_RATE   1505 non-null   float64
#  5   AMOUNT          1505 non-null   float64
#  6   CAT             1505 non-null   float64
#  7   TXN             3773 non-null   float64
#  8   CP              1046 non-null   object
#  9   DELIVERY_SCORE  1046 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 996.7+ KB
#
# Data Records
# -------------------------------------------------------
# Number of categorical variables: 5
# Number of numerical variables: 4
# ...

# %% [markdown]
# ## Understanding Numeric Variables - Active Users
#
# Active users are people has assigned credit cardand has any transaction

# %%
active = """
SELECT
ID,
usage_amount,
AMOUNT,
ROUND(usage_amount/AMOUNT,2) as credit_capacity,
(CASE WHEN ROUND(usage_amount/AMOUNT,2)>1 THEN 1 ELSE 0 END) as band_ratio,
nb_of_transactions,
amount_transaction_mean
FROM
(
SELECT
ID,
ROUND(SUM(TXN),2) as usage_amount,
sum(AMOUNT) as AMOUNT,
COUNT(TXN) as nb_of_transactions,
ROUND(SUM(TXN)/COUNT(TXN),0) as amount_transaction_mean
FROM
(SELECT 
ID,
strftime('%H:%M:00',substr(APPLICATION_DATE, 1, 8)) as DATE,
STATUS,
MOTIVE,
CAST(INTEREST_RATE AS INTEGER) as INTEREST_RATE,
CAST(AMOUNT AS REAL) as AMOUNT,
CAST(CAT AS INTEGER) as CAT,
CAST(TXN AS NUMERIC) as TXN,
CAST(CP AS TEXT) as CP,
CAST(DELIVERY_SCORE AS TEXT) as DELIVERY_SCORE
FROM credit_card_data)
group by ID)
where
usage_amount>0
"""

usage = query(active)
usage
# Out:
# Connection Established to rappi_db
#         ID  usage_amount   AMOUNT  credit_capacity  band_ratio  \
# 0        1        434.11   1300.0             0.33           0
# 1        4       5426.21  10000.0             0.54           0
# 2       11       6251.99  49800.0             0.13           0
# 3       17        152.04   6600.0             0.02           0
# 4       18       1131.12  16300.0             0.07           0
# ...    ...           ...      ...              ...         ...
# 1250  4966       2257.24   2600.0             0.87           0
# 1251  4970       3299.44  16100.0             0.20           0
# 1252  4991       2901.12   4300.0             0.67           0
# 1253  4998        886.80  25600.0             0.03           0
# 1254  4999      36084.48   1300.0            27.76           1
#
#       nb_of_transactions  amount_transaction_mean
# 0                      1                    434.0
# 1                      4                   1357.0
# ...

# %% [markdown]
# ----
#
# ## Explanation
#
# 1.- For the Credit Capacity Ratio, we need more information because it could be a misunderstanding. As we can see, label 1 means that there are quotients that exceeded the credit limit, therefore, perhaps we should analyze a vector that tells us the payments made and thus I think that this variable can be more accurate.
#
# 2.- The number of surprise transactions, I am not very distant between categories.
#
# 3.- The most important hard data is the impact of spending in relation to the line of credit, calculating the means of both vectors we realize that people, on average, do not use more than 15% of their line of credit. It would be interesting to investigate more in detail, but we can verify this with the distribution skewed to the left and perhaps an analysis of the cost of money will be important.
#
# 4.- La columna date tiene un formato %H:%M:%S por lo que me hubiera gustado tener mas detalle del mismo para los analisis por temporalidad y detectar fallas en procesos.

# %%
import matplotlib as mpl
from matplotlib.figure import Figure


fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2,2,figsize=(12,8))

fig.suptitle('Credit Card Usage - Customer Analysis')

ax1.hist(usage['band_ratio'])
ax1.grid(color='grey')
ax1.set_facecolor("white")
ax1.set_title('Number of cases by credit capacity label for detecting anomalies',fontsize=10)
ax1.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

ax2.hist(usage['nb_of_transactions'],color = "skyblue", ec="black")
ax2.grid(color='grey')
ax2.set_facecolor("white")
ax2.set_title('Distribution-Number of Transaction ',fontsize=10)
ax2.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

ax3.hist(usage['amount_transaction_mean'],color = "red", ec="black",bins=100,range= [0,5000])
ax3.grid(color='grey')
ax3.set_facecolor("white")
ax3.set_title('Distribution - Transaction expenditure mean',fontsize=10)
ax3.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

mean = round(usage['amount_transaction_mean'].mean())
ax3.text(1000, 44, f'Avg. Transaction: ${mean}',
        fontsize = 13, color ="red")

ax4.hist(usage['credit_capacity'],color = "green", ec="black",bins=100,range= [0,1])
ax4.grid(color='grey')
ax4.set_facecolor("white")
ax4.set_title('Distribution - Line of Credit usage %',fontsize=10)
ax4.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

mean_credit_line = round(usage['AMOUNT'].mean())

ax4.text(.2, 44, f'Mean Credit line: ${mean_credit_line}',
        fontsize = 13, color ="green")
# Out:
# Text(0.2, 44, 'Mean Credit line: $14499')

# %% [markdown]
# ----
#
# ## Understanding Numeric Variables - Application Users

# %% [markdown]
# ## Funnel Analysis
#
# 1.- Marketing campaigns reached 3341 potential users and there was only 2298 responses, i mean, 68% of total campaing.
#
# 2.- Risk Acceptance rate was 65%, and other words 35% of rejection rate. **RA = 1-(Rejected/risk)**
#
# 3.- Plastic card delivered rate was 69% and 31% digital. (Delivered/
# approved)
#
# I think that there should be a more exhaustive analysis regarding which clients we are targeting to achieve a greater response and therefore have better conversion rates. Another important point is the percentage of physical cards delivered where it would be interesting to measure what type of segment, that is, **are they from a particular age group? Don't have other credit cards? etc.**

# %%
waterfall = """
SELECT
COUNT(*) as count, 
STATUS
FROM
(SELECT 
ID,
strftime('%H:%M:00',substr(APPLICATION_DATE, 1, 8)) as DATE,
STATUS,
MOTIVE,
CAST(INTEREST_RATE AS INTEGER) as INTEREST_RATE,
CAST(AMOUNT AS REAL) as AMOUNT,
CAST(CAT AS INTEGER) as CAT,
CAST(TXN AS NUMERIC) as TXN,
CAST(CP AS TEXT) as CP,
CAST(DELIVERY_SCORE AS TEXT) as DELIVERY_SCORE
FROM credit_card_data)
where
STATUS is not null
group by STATUS
"""

waterfall = query(waterfall)

waterfall['order'] = np.where((waterfall['STATUS']=='RESPONSE') | (waterfall['STATUS']=='RISK'),1,
                             np.where(waterfall['STATUS']=='REJECTED',2,np.where(waterfall['STATUS']=='APPROVED',3,4)))

waterfall = waterfall.sort_values('order',ascending=True).set_index('order')


plt.bar(waterfall['STATUS'],waterfall['count'], color = 'orange')
xs = waterfall['STATUS'].astype(str)
ys = waterfall['count']

for x,y in zip(xs,ys):
    label = "{:.2f}".format(y)
    plt.annotate(label, 
                 (x,y), 
                 textcoords="offset points", 
                 xytext=(0,1), 
                 ha='center',
                fontsize=15) 
    
plt.title('Funnel Analysis - Waterfall',fontsize=20)
plt.rcParams["figure.figsize"] = (10,10)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()
# Out:
# Connection Established to rappi_db

# %% [markdown]
# ----
#
# ## Rejection reason

# %% [markdown]
# Although we had a 35% rejection, it is mostly explained by the delay in the MOP or rather in the credit history. The interesting thing is that in pairs it behaves almost uniformly, so it would be more interesting to have more detail about the categories.
#
# For income questions and some random cases; We could create some segmentation based on control groups and accept a certain % of those requests, along with:
#
# - With the current risk model, create an alternative evaluation route, that is, use a segmentation based on the acceptance criteria. As an example, if we talk about a payout probability, then **f(x) = x > Cut Off** (i.e. if we have a threshold of .6 for the general segment then for this segment we can create another configuration and set a new threshold as 0.3 for this experiment.)
#
# Of course this has additional benefits such as:
#
# 1. Higher acceptance rate.
# 2. Drive growth at a controlled level through experimentation.
# 3. Do not waste the budget of other areas such as Marketing clearly assigned by Finance, thus helping us to support spending.
# 4. By having groups, it is much easier to see what the origin problem is in terms of loss levels, however, as you may have noticed, we can adjust this cut-off point individually for each segment and this will help to have lower expected losses.
#
# Let's not forget the concept of expected losses...
#
# **Expected Loss (EL) = Probability of Default (PD) x Loss Given Default (LGD) x Exposure at Default (EAD)**
#
# |Category | Density|
# |-----------|:-----------:
# EMPTY |  21%
# INCOME | 21%
# MOP | 29%
# USAGE | 30%
#      **Total Distribution** |100%

# %%
reject_reason = """
SELECT
COUNT(*) as count, 
MOTIVE
FROM
(SELECT 
ID,
strftime('%H:%M:00',substr(APPLICATION_DATE, 1, 8)) as DATE,
STATUS,
MOTIVE,
CAST(INTEREST_RATE AS INTEGER) as INTEREST_RATE,
CAST(AMOUNT AS REAL) as AMOUNT,
CAST(CAT AS INTEGER) as CAT,
CAST(TXN AS NUMERIC) as TXN,
CAST(CP AS TEXT) as CP,
CAST(DELIVERY_SCORE AS TEXT) as DELIVERY_SCORE
FROM credit_card_data)
where
MOTIVE is not null
AND STATUS='REJECTED'
group by MOTIVE
"""

reason = query(reject_reason)
reason

plt.bar(reason['MOTIVE'],reason['count'], color = 'skyblue')
xm = reason['MOTIVE'].astype(str)
ym = reason['count']

for x,y in zip(xm,ym):
    label = "{:.2f}".format(y)
    plt.annotate(label, 
                 (x,y), 
                 textcoords="offset points", 
                 xytext=(0,1), 
                 ha='center',
                fontsize=15) 
    
plt.title('Reject Reason - Motive',fontsize=20)
plt.rcParams["figure.figsize"] = (10,10)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
nb_rejections = reason['count'].sum()
plt.text(.2, 200, f'Total Rejections: {nb_rejections}',
        fontsize = 13, color ="black")
plt.show()
# Out:
# Connection Established to rappi_db

# %% [markdown]
# ----
#
# ##  Card Deliverys & Customer Satisfaction

# %% [markdown]
# We can observe how in the postal codes that we deliver there is a greater concentration in cp 53100, it is important to follow up on these points in terms of credit behavior and avoid higher levels of losses in some areas.
#
# On the other hand, it was my expectation that the distribution of the delivery score would behave in a "normal" way where we see a greater concentration in 2 and 3, where it will be necessary to go further in the operations data to know if there is any note of the client towards us and evaluate to offer a better experience.

# %%
cp = """
SELECT
COUNT(*) as count, 
CP
FROM
(SELECT 
ID,
strftime('%H:%M:00',substr(APPLICATION_DATE, 1, 8)) as DATE,
STATUS,
MOTIVE,
CAST(INTEREST_RATE AS INTEGER) as INTEREST_RATE,
CAST(AMOUNT AS REAL) as AMOUNT,
CAST(CAT AS INTEGER) as CAT,
CAST(TXN AS NUMERIC) as TXN,
CAST(CP AS TEXT) as CP,
CAST(DELIVERY_SCORE AS TEXT) as DELIVERY_SCORE
FROM credit_card_data)
where
STATUS='DELIVERED'
group by CP
"""

rating = """
SELECT
COUNT(*) as count, 
DELIVERY_SCORE
FROM
(SELECT 
ID,
strftime('%H:%M:00',substr(APPLICATION_DATE, 1, 8)) as DATE,
STATUS,
MOTIVE,
CAST(INTEREST_RATE AS INTEGER) as INTEREST_RATE,
CAST(AMOUNT AS REAL) as AMOUNT,
CAST(CAT AS INTEGER) as CAT,
CAST(TXN AS NUMERIC) as TXN,
CAST(CP AS TEXT) as CP,
CAST(DELIVERY_SCORE AS TEXT) as DELIVERY_SCORE
FROM credit_card_data)
where
STATUS='DELIVERED'
group by DELIVERY_SCORE
"""

cp = query(cp)
rating = query(rating)
# Out:
# Connection Established to rappi_db
# Connection Established to rappi_db

# %%
import matplotlib as mpl
from matplotlib.figure import Figure


fig, (ax1, ax2) = plt.subplots(1,2,figsize=(12,8))

fig.suptitle('Demography Information & Rating')

ax1.bar(cp['CP'],cp['count'], color = 'skyblue',ec="black")
ax1.grid(color='grey')
ax1.set_facecolor("white")
ax1.set_title('Postal Code Distribution',fontsize=10)
ax1.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

ax2.barh(rating['DELIVERY_SCORE'],rating['count'],color = "orange", ec="black")
ax2.grid(color='grey')
ax2.set_facecolor("white")
ax2.set_title('Delivery Score Distribution',fontsize=10)
ax2.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

# %% [markdown]
# ----
#
# # Conclusions

# %% [markdown]
# We reach the final point where I will present some recommendations:
#
# - Studying these metrics with time variables would have been useful since it would help us to identify anomalies, bad executions or follow up on experiments. The UPDATE field transformed to DATE, was a field with %H-%M-%S format, it is useful up to a certain point, but the whole operation was derived at a time of 12 am, which at this late hour of the night can be rare some kind of usage behavior.
#
#
# - No doubt the rejection rates are somewhat high, therefore my strategy of control groups is a good option.
#
#
# - Study credit behavior, given that there are opportunities to encourage careful use of the card.
#
#
# - Keep in mind the Risk Appetite Statement to seek objective acceptance rates and thus meet business goals.
#
#
# - See why people prefer the physical card (Custom of the financial system?) and see why we have average satisfaction to make better decisions regarding the user experience.
